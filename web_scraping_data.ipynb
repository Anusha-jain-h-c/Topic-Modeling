# %% [markdown]
# # Web scraping for articles

# %%
! pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.2.1-py3-none-any.whl (33 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.9.3 soupsieve-2.2.1

# %%
! pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: certifi>=2017.4.17 in e:\npl_pjt\env\lib\site-packages (from requests) (2021.5.30)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Installing collected packages: urllib3, idna, chardet, requests
# Successfully installed chardet-4.0.0 idna-2.10 requests-2.25.1 urllib3-1.26.5

# %%
# Import libraries
import pandas as pd
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests

# %%
pagesToGet= 40

upperframe=[]  
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.politifact.com/factchecks/list/?page='+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('li',attrs={'class':'o-listicle__item'})
    print(len(links))
    filename="data.csv"
    f=open(filename,"w", encoding = 'utf-8')
    headers="Statement,Link,Date, Source, Label\n"
    f.write(headers)
    
    for j in links:
        Statement = j.find("div",attrs={'class':'m-statement__quote'}).text.strip()
        Link = "https://www.politifact.com"
        Link += j.find("div",attrs={'class':'m-statement__quote'}).find('a')['href'].strip()
        Date = j.find('div',attrs={'class':'m-statement__body'}).find('footer').text[-14:-1].strip()
        Source = j.find('div', attrs={'class':'m-statement__meta'}).find('a').text.strip()
        Label = j.find('div', attrs ={'class':'m-statement__content'}).find('img',attrs={'class':'c-image__original'}).get('alt').strip()
        frame.append((Statement,Link,Date,Source,Label))
        f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")
    upperframe.extend(frame)
f.close()
data=pd.DataFrame(upperframe, columns=['Statement','Link','Date','Source','Label'])
data.head()
# Out:
# processing page : 1
# https://www.politifact.com/factchecks/list/?page=1
# 30
# processing page : 2
# https://www.politifact.com/factchecks/list/?page=2
# 30
# processing page : 3
# https://www.politifact.com/factchecks/list/?page=3
# 30
# processing page : 4
# https://www.politifact.com/factchecks/list/?page=4
# 30
# processing page : 5
# https://www.politifact.com/factchecks/list/?page=5
# 30
# processing page : 6
# https://www.politifact.com/factchecks/list/?page=6
# 30
# processing page : 7
# https://www.politifact.com/factchecks/list/?page=7
# 30
# processing page : 8
# https://www.politifact.com/factchecks/list/?page=8
# 30
# processing page : 9
# https://www.politifact.com/factchecks/list/?page=9
# 30
# processing page : 10
# https://www.politifact.com/factchecks/list/?page=10
# 30
# processing page : 11
# https://www.politifact.com/factchecks/list/?page=11
# 30
# processing page : 12
# https://www.politifact.com/factchecks/list/?page=12
# 30
# processing page : 13
# https://www.politifact.com/factchecks/list/?page=13
# 30
# processing page : 14
# https://www.politifact.com/factchecks/list/?page=14
# 30
# processing page : 15
# https://www.politifact.com/factchecks/list/?page=15
# 30
# processing page : 16
# https://www.politifact.com/factchecks/list/?page=16
# 30
# processing page : 17
# https://www.politifact.com/factchecks/list/?page=17
# 30
# processing page : 18
# https://www.politifact.com/factchecks/list/?page=18
# 30
# processing page : 19
# https://www.politifact.com/factchecks/list/?page=19
# 30
# processing page : 20
# https://www.politifact.com/factchecks/list/?page=20
# 30
# processing page : 21
# https://www.politifact.com/factchecks/list/?page=21
# 30
# processing page : 22
# https://www.politifact.com/factchecks/list/?page=22
# 30
# processing page : 23
# https://www.politifact.com/factchecks/list/?page=23
# 30
# processing page : 24
# https://www.politifact.com/factchecks/list/?page=24
# 30
# processing page : 25
# https://www.politifact.com/factchecks/list/?page=25
# 30
# processing page : 26
# https://www.politifact.com/factchecks/list/?page=26
# 30
# processing page : 27
# https://www.politifact.com/factchecks/list/?page=27
# 30
# processing page : 28
# https://www.politifact.com/factchecks/list/?page=28
# 30
# processing page : 29
# https://www.politifact.com/factchecks/list/?page=29
# 30
# processing page : 30
# https://www.politifact.com/factchecks/list/?page=30
# 30
# processing page : 31
# https://www.politifact.com/factchecks/list/?page=31
# 30
# processing page : 32
# https://www.politifact.com/factchecks/list/?page=32
# 30
# processing page : 33
# https://www.politifact.com/factchecks/list/?page=33
# 30
# processing page : 34
# https://www.politifact.com/factchecks/list/?page=34
# 30
# processing page : 35
# https://www.politifact.com/factchecks/list/?page=35
# 30
# processing page : 36
# https://www.politifact.com/factchecks/list/?page=36
# 30
# processing page : 37
# https://www.politifact.com/factchecks/list/?page=37
# 30
# processing page : 38
# https://www.politifact.com/factchecks/list/?page=38
# 30
# processing page : 39
# https://www.politifact.com/factchecks/list/?page=39
# 30
# processing page : 40
# https://www.politifact.com/factchecks/list/?page=40
# 30
#                                            Statement  \
# 0  “World Health Organization wants to BAN all wo...
# 1  Says Greta Thunberg said, "the climate crisis ...
# 2  “The unvaccinated have escaped every single st...
# 3  Gov. Gavin Newsom has “no power or authority” ...
# 4  Says President John F. Kennedy said, “There ar...
#
#                                                 Link           Date  \
# 0  https://www.politifact.com/factchecks/2021/jun...  June 22, 2021
# 1  https://www.politifact.com/factchecks/2021/jun...  June 22, 2021
# 2  https://www.politifact.com/factchecks/2021/jun...  June 22, 2021
# 3  https://www.politifact.com/factchecks/2021/jun...  June 22, 2021
# 4  https://www.politifact.com/factchecks/2021/jun...  June 22, 2021
#
#             Source       Label
# 0         Bloggers       false
# 1  Instagram posts  pants-fire
# 2   Facebook posts       false
# 3   Facebook posts       false
# 4   Facebook posts       false

# %%
df = data.to_csv('df.csv')

# %%
data.tail(20)
# Out:
#                                               Statement  \
